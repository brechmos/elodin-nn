# %% [markdown]
# # Transfer Learning Hubble Image Similarity Display

# %%
# %matplotlib notebook

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))

import matplotlib.pyplot as plt
from tldist.similarity.similarity import Similarity
from tldist.similarity.display import SimilarityDisplay
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# ## Load the Database of Results

# %% [markdown]
# The assumption at this point is that a processing script was run that has calculated the cutouts of Hubble images, fingerprints and similarity. This would be stored in a database such as the one below.

# %%
from tldist.database import get_database
db = get_database('blitzdb', 'basic_notebook_20.db')

# %% [markdown]
# ## Get the Similarity to Display

# %% [markdown]
# Several types of similarities can be computed from the fingerprints. In this case we are going to use the [tSNE similarity](https://lvdmaaten.github.io/tsne/) calculated from the fingerprints.

# %%
similarities = db.find('similarity')
similarity_tsne = similarities[0]
# Out:
# INFO     2018-05-14 11:53:32,541 similarity __init__   Created tsne
# INFO     2018-05-14 11:53:32,542 similarity load       Loading the dictionary of information
# INFO     2018-05-14 11:53:32,544 similarity __init__   Created tsne
# INFO     2018-05-14 11:53:32,544 similarity load       Loading the dictionary of information

# %% [markdown]
# ## Display the Similarity for Interaction

# %% [markdown]
# Next we will display the similarity data and cutouts.  The tSNE plot is the 2D graph in the bottom left and when you hover in that region the corresponding cutout is displayed in the bottom right single image.  If you click in the tSNE plot, then the 8 corresponding images will be displayed in the 3x3 grid on the upper right (the first one is the one actually clicked on).  The top left shows the RA/DEC of the corresponding images on the Aitoff projection.
#
# An example similarity display is:
# ![image.png](attachment:image.png)

# %% [markdown]
# And next we have the intractive version:

# %%
sd = SimilarityDisplay(similarity_tsne, db)
# Out:
# <img src="data:image/png;base64,..." width="1599.9999653209347">
# /Users/crjones/miniconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# DEBUG    2018-05-14 11:53:33,709 cutout generator data_factory >>>>> There are 0 elems and looking for 1c2d98a5-62e0-4d9d-bae9-6fb96bc611ce (is in False)
# DEBUG    2018-05-14 11:53:33,710 cutout generator data_factory CREATING NEW DATA OBJECT #################################################
# INFO     2018-05-14 11:53:33,710 cutout     __init__    calling with cutout_processing [{'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}, {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}]
# INFO     2018-05-14 11:53:33,711 cutout processing load       dict is {'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}
# INFO     2018-05-14 11:53:33,712 cutout processing load       dict is {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}
# INFO     2018-05-14 11:53:33,712 cutout generator get_data   Data going to be returned
# DEBUG    2018-05-14 11:53:33,713 cutout generator get_data   LOADING  DATA ******************************************
# DEBUG    2018-05-14 11:53:33,713 cutout generator _load_and_process Data is not cached, so will need to load it
# INFO     2018-05-14 11:53:33,811 cutout     __init__   Creaing new cutout with data = Data located http://18.218.192.161:4123/ACSimages/j6jt03020_drz_small.jpg at RA/DEC [113.484125, -50.44308333333],  bounding_box = [0, 224, 0, 224], generator_parameters = {'cutout_type': 'FullImageCutoutGenerator', 'output_size': [224, 224], 'uuid': 'd449dfb0-40c0-41d1-b5fa-94867fec5501'}, cutout_rpcoessing = [{'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}, {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}], uuid_in 54b67efd-8c7a-4ad5-bf26-030d00e3db70
# INFO     2018-05-14 11:53:33,812 cutout     get_data
# /Users/crjones/miniconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# DEBUG    2018-05-14 11:53:34,082 cutout generator data_factory >>>>> There are 1 elems and looking for 33834f37-4fdb-497e-8965-3d5dd0f7c2ed (is in False)
# DEBUG    2018-05-14 11:53:34,082 cutout generator data_factory CREATING NEW DATA OBJECT #################################################
# INFO     2018-05-14 11:53:34,083 cutout     __init__    calling with cutout_processing [{'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}, {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}]
# INFO     2018-05-14 11:53:34,083 cutout processing load       dict is {'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}
# INFO     2018-05-14 11:53:34,084 cutout processing load       dict is {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}
# INFO     2018-05-14 11:53:34,084 cutout generator get_data   Data going to be returned
# DEBUG    2018-05-14 11:53:34,085 cutout generator get_data   LOADING  DATA ******************************************
# DEBUG    2018-05-14 11:53:34,085 cutout generator _load_and_process Data is not cached, so will need to load it
# INFO     2018-05-14 11:53:34,134 cutout     __init__   Creaing new cutout with data = Data located http://18.218.192.161:4123/ACSimages/j59l54010_drz_small.jpg at RA/DEC [49.5375, -25.6],  bounding_box = [0, 224, 0, 224], generator_parameters = {'cutout_type': 'FullImageCutoutGenerator', 'output_size': [224, 224], 'uuid': 'd449dfb0-40c0-41d1-b5fa-94867fec5501'}, cutout_rpcoessing = [{'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}, {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}], uuid_in d29cc170-aa62-4a07-a2aa-f4bdf91a7358
# INFO     2018-05-14 11:53:34,135 cutout     get_data
# DEBUG    2018-05-14 11:53:34,595 cutout generator data_factory >>>>> There are 2 elems and looking for 00b8814b-a936-4407-a226-76cd921f0712 (is in False)
# DEBUG    2018-05-14 11:53:34,597 cutout generator data_factory CREATING NEW DATA OBJECT #################################################
# INFO     2018-05-14 11:53:34,598 cutout     __init__    calling with cutout_processing [{'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}, {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}]
# INFO     2018-05-14 11:53:34,599 cutout processing load       dict is {'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}
# INFO     2018-05-14 11:53:34,600 cutout processing load       dict is {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}
# INFO     2018-05-14 11:53:34,600 cutout generator get_data   Data going to be returned
# DEBUG    2018-05-14 11:53:34,601 cutout generator get_data   LOADING  DATA ******************************************
# DEBUG    2018-05-14 11:53:34,602 cutout generator _load_and_process Data is not cached, so will need to load it
# INFO     2018-05-14 11:53:34,639 cutout     __init__   Creaing new cutout with data = Data located http://18.218.192.161:4123/ACSimages/j6d508010_drz_small.jpg at RA/DEC [10.773125, 41.28425],  bounding_box = [0, 224, 0, 224], generator_parameters = {'cutout_type': 'FullImageCutoutGenerator', 'output_size': [224, 224], 'uuid': 'd449dfb0-40c0-41d1-b5fa-94867fec5501'}, cutout_rpcoessing = [{'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}, {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}], uuid_in afbd187d-7240-4aef-9076-ef468edc0651
# INFO     2018-05-14 11:53:34,641 cutout     get_data
# DEBUG    2018-05-14 11:53:34,913 cutout generator data_factory >>>>> There are 3 elems and looking for 4b378ec4-c6a4-41e4-801a-8e7d56b4c20c (is in False)
# DEBUG    2018-05-14 11:53:34,914 cutout generator data_factory CREATING NEW DATA OBJECT #################################################
# INFO     2018-05-14 11:53:34,915 cutout     __init__    calling with cutout_processing [{'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}, {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}]
# INFO     2018-05-14 11:53:34,915 cutout processing load       dict is {'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}
# INFO     2018-05-14 11:53:34,916 cutout processing load       dict is {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}
# INFO     2018-05-14 11:53:34,917 cutout generator get_data   Data going to be returned
# DEBUG    2018-05-14 11:53:34,918 cutout generator get_data   LOADING  DATA ******************************************
# DEBUG    2018-05-14 11:53:34,918 cutout generator _load_and_process Data is not cached, so will need to load it
# INFO     2018-05-14 11:53:34,954 cutout     __init__   Creaing new cutout with data = Data located http://18.218.192.161:4123/ACSimages/j6d508020_drz_small.jpg at RA/DEC [10.773125, 41.28425],  bounding_box = [0, 224, 0, 224], generator_parameters = {'cutout_type': 'FullImageCutoutGenerator', 'output_size': [224, 224], 'uuid': 'd449dfb0-40c0-41d1-b5fa-94867fec5501'}, cutout_rpcoessing = [{'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}, {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}], uuid_in f9905daa-5a1c-4e47-985e-9869da1383b3
# INFO     2018-05-14 11:53:34,955 cutout     get_data
# DEBUG    2018-05-14 11:53:35,202 cutout generator data_factory >>>>> There are 4 elems and looking for 358c4bb4-d618-4dd2-8265-f1fe098a5f72 (is in False)
# DEBUG    2018-05-14 11:53:35,203 cutout generator data_factory CREATING NEW DATA OBJECT #################################################
# INFO     2018-05-14 11:53:35,203 cutout     __init__    calling with cutout_processing [{'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}, {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}]
# INFO     2018-05-14 11:53:35,204 cutout processing load       dict is {'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}
# INFO     2018-05-14 11:53:35,205 cutout processing load       dict is {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}
# INFO     2018-05-14 11:53:35,205 cutout generator get_data   Data going to be returned
# DEBUG    2018-05-14 11:53:35,206 cutout generator get_data   LOADING  DATA ******************************************
# DEBUG    2018-05-14 11:53:35,207 cutout generator _load_and_process Data is not cached, so will need to load it
# INFO     2018-05-14 11:53:35,260 cutout     __init__   Creaing new cutout with data = Data located http://18.218.192.161:4123/ACSimages/j6d509010_drz_small.jpg at RA/DEC [10.47787916667, 40.94661111111],  bounding_box = [0, 224, 0, 224], generator_parameters = {'cutout_type': 'FullImageCutoutGenerator', 'output_size': [224, 224], 'uuid': 'd449dfb0-40c0-41d1-b5fa-94867fec5501'}, cutout_rpcoessing = [{'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}, {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}], uuid_in 8abc3b85-18f7-401a-9acf-a0d511cf484b
# INFO     2018-05-14 11:53:35,260 cutout     get_data
# DEBUG    2018-05-14 11:53:35,501 cutout generator data_factory >>>>> There are 5 elems and looking for ac6c793a-282b-4895-8407-747afb251c04 (is in False)
# DEBUG    2018-05-14 11:53:35,502 cutout generator data_factory CREATING NEW DATA OBJECT #################################################
# INFO     2018-05-14 11:53:35,502 cutout     __init__    calling with cutout_processing [{'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}, {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}]
# INFO     2018-05-14 11:53:35,503 cutout processing load       dict is {'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}
# INFO     2018-05-14 11:53:35,503 cutout processing load       dict is {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}
# INFO     2018-05-14 11:53:35,504 cutout generator get_data   Data going to be returned
# DEBUG    2018-05-14 11:53:35,505 cutout generator get_data   LOADING  DATA ******************************************
# DEBUG    2018-05-14 11:53:35,505 cutout generator _load_and_process Data is not cached, so will need to load it
# INFO     2018-05-14 11:53:35,555 cutout     __init__   Creaing new cutout with data = Data located http://18.218.192.161:4123/ACSimages/j6d509020_drz_small.jpg at RA/DEC [10.47787916667, 40.94661111111],  bounding_box = [0, 224, 0, 224], generator_parameters = {'cutout_type': 'FullImageCutoutGenerator', 'output_size': [224, 224], 'uuid': 'd449dfb0-40c0-41d1-b5fa-94867fec5501'}, cutout_rpcoessing = [{'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}, {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}], uuid_in 1d0eeda2-a692-4083-8c5d-bd79286bae48
# INFO     2018-05-14 11:53:35,556 cutout     get_data
# DEBUG    2018-05-14 11:53:35,802 cutout generator data_factory >>>>> There are 6 elems and looking for a196af08-6382-4cd9-93a7-fbb02f5e042c (is in False)
# DEBUG    2018-05-14 11:53:35,802 cutout generator data_factory CREATING NEW DATA OBJECT #################################################
# INFO     2018-05-14 11:53:35,803 cutout     __init__    calling with cutout_processing [{'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}, {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}]
# INFO     2018-05-14 11:53:35,803 cutout processing load       dict is {'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}
# INFO     2018-05-14 11:53:35,804 cutout processing load       dict is {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}
# INFO     2018-05-14 11:53:35,805 cutout generator get_data   Data going to be returned
# DEBUG    2018-05-14 11:53:35,805 cutout generator get_data   LOADING  DATA ******************************************
# DEBUG    2018-05-14 11:53:35,806 cutout generator _load_and_process Data is not cached, so will need to load it
# INFO     2018-05-14 11:53:35,859 cutout     __init__   Creaing new cutout with data = Data located http://18.218.192.161:4123/ACSimages/j6d510010_drz_small.jpg at RA/DEC [10.47787916667, 40.94661111111],  bounding_box = [0, 224, 0, 224], generator_parameters = {'cutout_type': 'FullImageCutoutGenerator', 'output_size': [224, 224], 'uuid': 'd449dfb0-40c0-41d1-b5fa-94867fec5501'}, cutout_rpcoessing = [{'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}, {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}], uuid_in 540c0ea1-ff5d-45a4-82a8-4fafe3ed679e
# INFO     2018-05-14 11:53:35,860 cutout     get_data
# DEBUG    2018-05-14 11:53:36,097 cutout generator data_factory >>>>> There are 7 elems and looking for 7b751acf-9713-4fff-b277-c4dd0984c2bc (is in False)
# DEBUG    2018-05-14 11:53:36,098 cutout generator data_factory CREATING NEW DATA OBJECT #################################################
# INFO     2018-05-14 11:53:36,098 cutout     __init__    calling with cutout_processing [{'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}, {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}]
# INFO     2018-05-14 11:53:36,099 cutout processing load       dict is {'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}
# INFO     2018-05-14 11:53:36,099 cutout processing load       dict is {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}
# INFO     2018-05-14 11:53:36,100 cutout generator get_data   Data going to be returned
# DEBUG    2018-05-14 11:53:36,100 cutout generator get_data   LOADING  DATA ******************************************
# DEBUG    2018-05-14 11:53:36,101 cutout generator _load_and_process Data is not cached, so will need to load it
# INFO     2018-05-14 11:53:36,151 cutout     __init__   Creaing new cutout with data = Data located http://18.218.192.161:4123/ACSimages/j6d510020_drz_small.jpg at RA/DEC [10.47787916667, 40.94661111111],  bounding_box = [0, 224, 0, 224], generator_parameters = {'cutout_type': 'FullImageCutoutGenerator', 'output_size': [224, 224], 'uuid': 'd449dfb0-40c0-41d1-b5fa-94867fec5501'}, cutout_rpcoessing = [{'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}, {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}], uuid_in dd0f5c92-dd49-48da-b4a6-053e44f63474
# INFO     2018-05-14 11:53:36,152 cutout     get_data
# DEBUG    2018-05-14 11:53:36,390 cutout generator data_factory >>>>> There are 8 elems and looking for 59378d4d-46d3-482f-b4ed-4da080a5245b (is in False)
# DEBUG    2018-05-14 11:53:36,390 cutout generator data_factory CREATING NEW DATA OBJECT #################################################
# INFO     2018-05-14 11:53:36,391 cutout     __init__    calling with cutout_processing [{'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}, {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}]
# INFO     2018-05-14 11:53:36,391 cutout processing load       dict is {'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}
# INFO     2018-05-14 11:53:36,392 cutout processing load       dict is {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}
# INFO     2018-05-14 11:53:36,393 cutout generator get_data   Data going to be returned
# DEBUG    2018-05-14 11:53:36,393 cutout generator get_data   LOADING  DATA ******************************************
# DEBUG    2018-05-14 11:53:36,394 cutout generator _load_and_process Data is not cached, so will need to load it
# INFO     2018-05-14 11:53:36,445 cutout     __init__   Creaing new cutout with data = Data located http://18.218.192.161:4123/ACSimages/j6d511010_drz_small.jpg at RA/DEC [10.47780416667, 40.94652777778],  bounding_box = [0, 224, 0, 224], generator_parameters = {'cutout_type': 'FullImageCutoutGenerator', 'output_size': [224, 224], 'uuid': 'd449dfb0-40c0-41d1-b5fa-94867fec5501'}, cutout_rpcoessing = [{'cutout_processing_type': 'crop', 'parameters': {'output_size': [15, -15, 15, -15]}}, {'cutout_processing_type': 'resize', 'parameters': {'output_size': [224, 224]}}], uuid_in 0ef8e3e8-3eda-43f9-a39e-8879522840cc
# INFO     2018-05-14 11:53:36,446 cutout     get_data

# %%
sd._similar_images_axis._text_axis.set_ylim((1,0))
# Out:
# (1, 0)
