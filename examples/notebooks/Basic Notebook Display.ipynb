# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
from tldist.similarity.similarity import Similarity
from tldist.similarity.display import SimilarityDisplay

# %%
from tldist.database import get_database
db = get_database('blitzdb', 'basic_notebook.db')
# Out:
# DEBUG    2018-05-11 09:00:53,665 database   get_database comparing mongo to blitzdb
# DEBUG    2018-05-11 09:00:53,666 database   get_database comparing blitzdb to blitzdb
# DEBUG    2018-05-11 09:00:53,667 database   get_database    ...same
# DEBUG    2018-05-11 09:00:53,667 database   get_database comparing unqlite to blitzdb

# %%
similarities = db.find('similarity')
similarity_tsne = Similarity.similarity_factory(similarities[0])
# Out:
# INFO     2018-05-11 09:00:55,930 similarity __init__   Created tsne
# INFO     2018-05-11 09:00:55,931 similarity load       Loading the dictionary of information

# %%
sd = SimilarityDisplay(similarity_tsne, db)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# INFO     2018-05-11 09:01:08,315 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:01:08,485 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:01:08,503 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:01:08,559 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:01:08,564 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:01:08,602 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:01:08,609 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:01:08,667 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:01:08,672 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:01:08,754 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:01:08,787 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:01:08,843 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:01:08,850 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:01:08,945 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:01:08,949 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:01:08,993 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:01:08,997 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:01:09,038 cutout generator get_data   Data going to be returned
