# %% [markdown]
# # Transfer Learning Hubble Image Similarity Display

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
from tldist.similarity.similarity import Similarity
from tldist.similarity.display import SimilarityDisplay

# %% [markdown]
# ## Load the Database of Results

# %% [markdown]
# The assumption at this point is that a processing script was run that has calculated the cutouts of Hubble images, fingerprints and similarity. This would be stored in a database such as the one below.

# %%
from tldist.database import get_database
db = get_database('blitzdb', 'basic_notebook_100.db')

# %% [markdown]
# ## Get the Similarity to Display

# %% [markdown]
# Several types of similarities can be computed from the fingerprints. In this case we are going to use the [tSNE similarity](https://lvdmaaten.github.io/tsne/) calculated from the fingerprints.

# %%
similarities = db.find('similarity')
similarity_tsne = similarities[0]
# Out:
# INFO     2018-05-11 12:16:29,889 similarity __init__   Created tsne
# INFO     2018-05-11 12:16:29,890 similarity load       Loading the dictionary of information

# %% [markdown]
# ## Display the Similarity for Interaction

# %% [markdown]
# Next we will display the similarity data and cutouts.  The tSNE plot is the 2D graph in the bottom left and when you hover in that region the corresponding cutout is displayed in the bottom right single image.  If you click in the tSNE plot, then the 8 corresponding images will be displayed in the 3x3 grid on the upper right (the first one is the one actually clicked on).  The top left shows the RA/DEC of the corresponding images on the Aitoff projection.
#
# An example similarity display is:
# ![image.png](attachment:image.png)

# %% [markdown]
# And next we have the intractive version:

# %%
sd = SimilarityDisplay(similarity_tsne, db)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# INFO     2018-05-11 12:16:31,547 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 12:16:31,611 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 12:16:31,614 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 12:16:31,664 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 12:16:31,667 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 12:16:31,717 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 12:16:31,720 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 12:16:31,756 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 12:16:31,759 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 12:16:31,809 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 12:16:31,812 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 12:16:31,864 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 12:16:31,867 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 12:16:31,919 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 12:16:31,922 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 12:16:31,980 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 12:16:31,983 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 12:16:32,035 cutout generator get_data   Data going to be returned
