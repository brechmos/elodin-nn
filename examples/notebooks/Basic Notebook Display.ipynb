# %% [markdown]
# # Transfer Learning Hubble Image Similarity Display

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
from tldist.similarity.similarity import Similarity
from tldist.similarity.display import SimilarityDisplay

# %% [markdown]
# ## Load the Database of Results

# %%
from tldist.database import get_database
db = get_database('blitzdb', 'basic_notebook_100.db')

# %% [markdown]
# ## Get the Similarity to Display

# %%
similarities = db.find('similarity')
similarity_tsne = Similarity.similarity_factory(similarities[0])
# Out:
# INFO     2018-05-11 09:22:32,815 similarity __init__   Created tsne
# INFO     2018-05-11 09:22:32,816 similarity load       Loading the dictionary of information

# %% [markdown]
# ## Display the Similarity for Interaction

# %%
sd = SimilarityDisplay(similarity_tsne, db)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# INFO     2018-05-11 09:22:56,824 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:22:56,897 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:22:56,900 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:22:56,948 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:22:56,952 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:22:57,002 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:22:57,005 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:22:57,040 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:22:57,043 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:22:57,095 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:22:57,098 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:22:57,158 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:22:57,162 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:22:57,214 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:22:57,218 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:22:57,269 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:22:57,273 cutout generator get_data   Data going to be returned
# INFO     2018-05-11 09:22:57,328 cutout generator get_data   Data going to be returned
