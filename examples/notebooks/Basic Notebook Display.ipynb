# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
from tldist.similarity.similarity import Similarity
from tldist.similarity.display import SimilarityDisplay

# %%
from tldist.database import get_database
db = get_database('blitzdb', 'basic_notebook.db')

# %%
from tldist.database import get_database
db = get_database('blitzdb', 'basic_notebook.db')
similarities = db.find('similarity')
similarity_tsne = Similarity.similarity_factory(similarities[0])

# %%
similarity_tsne
# Out:
# Similarity tsne based on ['3ee75f57-23ab-4f43-b40e-2f5770789e73', 'ee0ef1bd-7be7-4d7d-8adb-2204e69a2bac', 'f7488924-603e-4e93-9779-0c5da08e069d']...

# %%
sd = SimilarityDisplay(similarity_tsne)
sd.display()
# Out:
# <img src="data:image/png;base64,..." width="1600">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-2ecb195859dc> in <module>()
#       1 sd = SimilarityDisplay(similarity_tsne)
# ----> 2 sd.display()
#
# ~/Documents/Science/TL/tldist/tldist/similarity/display.py in display(self)
#      25
#      26         # Sub window for on move closest fingerprint
# ---> 27         self.closest_plot = ImageDisplay(self.fig, [0.35, 0.01, 0.15, 0.15])
#      28         self.axis_closest.set_xticks([])
#      29         self.axis_closest.set_yticks([])
#
# ~/Documents/Science/TL/tldist/tldist/similarity/display.py in __init__(self, *args, **kwargs)
#     175
#     176         self._data = plt.imshow(np.zeros((224, 224)), cmap=plt.gray())
# --> 177         self.set_xticks([])
#     178         self.set_yticks([])
#     179         self.set_xlabel('')
#
# ~/miniconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in set_xticks(self, ticks, minor)
#    3045             Default is ``False``.
#    3046         """
# -> 3047         ret = self.xaxis.set_ticks(ticks, minor=minor)
#    3048         self.stale = True
#    3049         return ret
#
# AttributeError: 'ImageDisplay' object has no attribute 'xaxis'

# %%
aa = plt.axes([0.1, 0.1, 0.3, 0.3])

# %%
aa

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

class A(matplotlib.axes._axes.Axes):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self._image = self.imshow(np.zeros((224,224)), cmap=plt.gray())
        self.set_xticks([])
        self.set_yticks([])
        self.set_xlabel('')
        self.set_ylabel('')
        
        
fig = plt.figure(2, figsize=[10,8])
a = A(fig, [0.1, 0.1, 0.2, 0.1])
plt.show(block=False)
# Out:
# <img src="data:image/png;base64,..." width="1000">
