# %%
# %matplotlib notebook
from matplotlib.pyplot import *

import sys
toadd = '..'
if toadd not in sys.path:
    b = sys.path
    sys.path = [toadd] + b

import glob
import os
import numpy as np

from transfer_learning import TransferLearning, TransferLearningDisplay
from data_processing import MedianFilterData, ZoomData, GrayScaleData
from cutouts import BasicCutouts, BlobCutouts
from fingerprint import FingerprintResnet, FingerprintInceptionV3
from similarity import tSNE, Jaccard

import logging
logging.basicConfig(format='%(levelname)-6s: %(name)-10s %(asctime)-15s  %(message)s')
log = logging.getLogger("Runme")
log.setLevel(logging.WARNING)

# %% [markdown]
# # Input and Output Directories

# %%
input_file_pattern = 'hst_heritage_data/[a-h]*.???'
output_directory = './'

input_files = glob.glob(input_file_pattern)

# %% [markdown]
# # Setup Fingerprint Calculator

# %%
fingerprint_resnet = FingerprintInceptionV3()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Setup Pre-Processing of Data

# %%
data_processing = []

# %% [markdown]
# #  Create Cutout

# %%
blob_cutouts = BlobCutouts(output_size=224, gaussian_smoothing_sigma=10, mean_threshold=1.5)

# %% [markdown]
# # Create Data Processing Instance

# %%
tl = TransferLearning(blob_cutouts, data_processing, fingerprint_resnet)
tl.set_files(input_files)

# %% [markdown]
# # Calculate Fingerprints

# %%
fingerprints = tl.calculate(display=False)
# Out:
# INFO  : TransferLearning 2018-02-22 22:01:08,767  Processing filename hst_heritage_data/abel.jpg
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/filters/_gaussian.py:22: skimage_deprecation: Function ``gaussian_filter`` is deprecated. Use ``skimage.filters.gaussian`` instead.
#   multichannel=None, preserve_range=False, truncate=4.0):
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01:12,789  Calculate 200 predictions took 0.13402104377746582s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01:13,048  Calculate 200 predictions took 0.12880277633666992s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01:13,247  Calculate 200 predictions took 0.12702107429504395s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01:13,449  Calculate 200 predictions took 0.11872482299804688s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01:13,650  Calculate 200 predictions took 0.12623000144958496s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01:13,966  Calculate 200 predictions took 0.20267224311828613s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01:14,173  Calculate 200 predictions took 0.13061094284057617s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01:14,377  Calculate 200 predictions took 0.12769269943237305s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01:14,581  Calculate 200 predictions took 0.1318650245666504s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01:14,786  Calculate 200 predictions took 0.13218307495117188s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01:15,105  Calculate 200 predictions took 0.18134093284606934s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01:15,306  Calculate 200 predictions took 0.12959003448486328s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01:15,511  Calculate 200 predictions took 0.13370394706726074s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01:15,826  Calculate 200 predictions took 0.24338197708129883s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01:16,028  Calculate 200 predictions took 0.12603211402893066s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01:16,350  Calculate 200 predictions took 0.24650287628173828s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01:16,672  Calculate 200 predictions took 0.24868011474609375s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01:16,871  Calculate 200 predictions took 0.1257178783416748s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01:17,072  Calculate 200 predictions took 0.12958192825317383s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01:17,275  Calculate 200 predictions took 0.13117432594299316s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01:17,483  Calculate 200 predictions took 0.13513827323913574s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01:17,682  Calculate 200 predictions took 0.12630105018615723s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01:17,880  Calculate 200 predictions took 0.12565898895263672s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01:18,085  Calculate 200 predictions took 0.13213586807250977s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01:18,284  Calculate 200 predictions took 0.12853217124938965s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:01

# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:51,332  Calculate 200 predictions took 0.13383007049560547s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:51,496  Calculate 200 predictions took 0.13453006744384766s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:51,669  Calculate 200 predictions took 0.14372491836547852s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:51,832  Calculate 200 predictions took 0.1351008415222168s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:52,018  Calculate 200 predictions took 0.15500092506408691s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:52,177  Calculate 200 predictions took 0.12975525856018066s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:52,335  Calculate 200 predictions took 0.1282050609588623s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:52,496  Calculate 200 predictions took 0.13213896751403809s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:52,666  Calculate 200 predictions took 0.13785982131958008s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:52,834  Calculate 200 predictions took 0.13867521286010742s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:53,002  Calculate 200 predictions took 0.13938212394714355s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:53,206  Calculate 200 predictions took 0.12653708457946777s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:53,368  Calculate 200 predictions took 0.13251304626464844s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:53,535  Calculate 200 predictions took 0.12756896018981934s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:53,691  Calculate 200 predictions took 0.1280069351196289s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:53,854  Calculate 200 predictions took 0.13373613357543945s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:54,019  Calculate 200 predictions took 0.13248395919799805s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:54,191  Calculate 200 predictions took 0.13207721710205078s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:54,362  Calculate 200 predictions took 0.14049315452575684s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:54,526  Calculate 200 predictions took 0.1338660717010498s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:54,692  Calculate 200 predictions took 0.13480806350708008s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:54,853  Calculate 200 predictions took 0.13044118881225586s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:55,020  Calculate 200 predictions took 0.13584184646606445s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:55,177  Calculate 200 predictions took 0.12967896461486816s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:55,342  Calculate 200 predictions took 0.13612675666809082s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:55,506  Calculate 200 predictions took 0.13501405715942383s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:55,670  Calculate 200 predictions took 0.13402175903320312s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:55,838  Calculate 200 predictions took 0.13651108741760254s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:56,056  Calculate 200 predictions took 0.18798112869262695s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:56,241  Calculate 200 predictions took 0.14429783821105957s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:56,412  Calculate 200 predictions took 0.14124584197998047s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:56,579  Calculate 200 predictions took 0.1353762149810791s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:56,748  Calculate 200 predictions took 0.13938617706298828s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:56,920  Calculate 200 predictions took 0.14162588119506836s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:57,122  Calculate 200 predictions took 0.14141201972961426s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:57,288  Calculate 200 predictions took 0.13535118103027344s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:57,456  Calculate 200 predictions took 0.1378340721130371s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:57,628  Calculate 200 predictions took 0.14330387115478516s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:57,798  Calculate 200 predictions took 0.1376481056213379s
# /Users/crjones/miniconda3/envs/transfer-learning/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# INFO  : Fingerprint 2018-02-22 22:08:57,963  Calculate 200 predictions took 0.1350538730621338s

# %% [markdown]
# # Save Data

# %%
# tl.save('temp.pck')

# %% [markdown]
# # Load Data

# %%
#tl = TransferLearning.load(filename)

# %% [markdown]
# # Create Similarity Instance

# %%
# Calculate hte similarity
similarity = Jaccard()
#similarity = tSNE()
#similarity = Distance(metric='cityblock')
# Out:
# INFO  : Similarity 2018-02-22 22:08:57,996  Created jaccard

# %% [markdown]
# # Create Display Instance

# %%
tld = TransferLearningDisplay(similarity)

# %% [markdown]
# # Display and Interact with Similarities

# %%
tld.show(tl.fingerprints)
# Out:
# INFO  : Similarity 2018-02-22 22:08:58,013  Going to calculate Jaccard from 1887 fingerprints
# <img src="data:image/png;base64,..." width="1000">
